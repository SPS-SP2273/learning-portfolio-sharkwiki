# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
max_vol = [59.9, 74.1, 75.9, 77.0, 81.7, 72.4, 67.8, 86.4, 56.5, 62, 67, 55.1, 61.5, 60.2, 55.9, 58.2, 60.3, 54.2, 65.5, 60, 58.2]
ave_vol = [51.6, 69.4, 67.9, 66.5, 78.5, 65.1, 53.7, 79.4, 50, 56.9, 61.5, 48.4, 57.6, 57.5, 48.9, 54, 57.5, 48.3, 61.2, 56.3, 48.3]
temp = [27.8, 25.7, 25.9, 28.4, 28.7, 26.6, 29.5, 29.4, 29.1, 28.5, 27.9, 26.9, 28.4, 27.5, 26.4, 28.6, 27.9, 28, 27.8, 27.6, 25.7]
humidity = [76, 72, 82, 82, 85, 86, 74, 78, 80, 72, 77, 82, 72, 76, 82, 77, 79, 82, 75, 77, 81]
x = [0, 244, 645, 1416, 1669, 2076, 2905, 3121, 3519, 4315, 4560, 4954, 5794, 5989, 6397, 7198, 7440, 7837, 8620, 8869, 9278]

plt.plot(x, max_vol, label='Maximum Volume in 1 Minute (dB)', color='blue')
plt.plot(x, ave_vol, label='Average Volume in 1 Minute (dB)', color='green')
plt.plot(x, humidity, label='Local Humidity (%)', color='pink')
plt.grid(alpha=.25)
plt.legend(loc='upper left')
plt.ylim([30,100])

plt.twinx()
plt.plot(x, temp, label='Local Temperature (°C)', color='purple')
plt.legend(loc='lower left')
plt.ylim([20,30])
# Out:
# (20.0, 30.0)

# %% [markdown]
# # 1 A simple plot

# %% [markdown]
# ## 1.1 Let’s look at some code.

# %%
# Some data for plotting
x = [0, 1, 2, 3, 4, 5, 6]
y_1 = [0, 2, 4, 6, 8, 10, 12]
y_2 = [0, 3, 6, 9, 12, 15, 18]

# Let's start plotting
plt.plot(x, y_1, label='Y values',
         color='blue', linestyle='dashed')
plt.xlabel('x-values')
plt.ylabel('y-values')
plt.title('X vs Y')
plt.grid(alpha=.25)
plt.legend(loc='lower left')

# %% [markdown]
# ### Things to note

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 plt.plot(x, y, color='red', linestyle='dashed', linewidth=2)
#
# NameError: name 'y' is not defined

# %% [markdown]
# ## 1.2 Adding another plot

# %% [markdown]
# ## 1.3 Yet another plot but with error bars

# %% [markdown]
# # 2 Better with NumPy

# %% [markdown]
# ## 2.1 Adding mathematical functions

# %% [markdown]
# ## We need another axis!

# %% [markdown]
# ### Things to note

# %%
# Your code here

# %% [markdown]
# # 3 Saving to disc

# %% [markdown]
# # 4 A real example: Global Warming

# %% [markdown]
# ## 4.1 Plotting data from files

# %% [markdown]
# ## 4.2 Styles

# %% [markdown]
# ### xkcd!

# %%
# Your code here

# %% [markdown]
# ### Resetting styles

# %%
# Your code here
